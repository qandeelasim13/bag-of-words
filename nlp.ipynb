# %%
x="the university of fasialabad is a private institute. imparting high quality higher education at undergraduate.graduate and postgraduate level"

# %%
import nltk
nltk.download('punkt')   # Tokenizer ke liye zaroori data
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ideal\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
w = word_tokenize(x)

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\ideal\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
 True
# Out:
# True

# %%
from nltk.tokenize import word_tokenize

# %%
print(word_tokenize(x))
print(sent_tokenize(x))
# Out:
# ['the', 'university', 'of', 'fasialabad', 'is', 'a', 'private', 'institute', '.', 'imparting', 'high', 'quality', 'higher', 'education', 'at', 'undergraduate.graduate', 'and', 'postgraduate', 'level']
# ['the university of fasialabad is a private institute.', 'imparting high quality higher education at undergraduate.graduate and postgraduate level']

# %%
from nltk.tag import pos_tag

# %%
# POS tagging
p = pos_tag(w)

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\ideal\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
p
# Out:
# [('ChatGPT', 'NNP'),
#  ('makes', 'VBZ'),
#  ('programming', 'VBG'),
#  ('easier', 'JJR')]
